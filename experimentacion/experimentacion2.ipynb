# %% [markdown]
# ## Lectura de archivos

# %%
import pickle
import pandas as pd

# %%
times_sequential = pd.read_pickle('search_times_knn_sequential.pkl')
times_highd = pd.read_pickle('search_times_knn_highd.pkl')
times_rtree = pd.read_pickle('search_times_knn_rtree.pkl')

# %%
times_highd
# Out:
# {25: [0.00014495849609375,
#   0.0002892017364501953,
#   0.014957904815673828,
#   0.0005288124084472656],
#  50: [0.00020503997802734375,
#   0.00028824806213378906,
#   0.0027031898498535156,
#   0.00036334991455078125],
#  100: [0.0003170967102050781,
#   0.0004100799560546875,
#   0.0006995201110839844,
#   0.0006766319274902344],
#  128: [0.0004088878631591797,
#   0.0006666183471679688,
#   0.0008382797241210938,
#   0.004073619842529297]}

# %%
times_rtree
# Out:
# {25: [0.0005662441253662109,
#   0.0008878707885742188,
#   0.0017952919006347656,
#   0.002825498580932617],
#  50: [0.0006802082061767578,
#   0.0012617111206054688,
#   0.004136323928833008,
#   0.004471540451049805],
#  100: [0.0010619163513183594,
#   0.0022683143615722656,
#   0.0046956539154052734,
#   0.007608652114868164],
#  128: [0.0014328956604003906,
#   0.003154754638671875,
#   0.0066683292388916016,
#   0.010486602783203125]}

# %%
times_sequential
# Out:
# {25: [0.007271289825439453,
#   0.01410818099975586,
#   0.028023481369018555,
#   0.042496681213378906],
#  50: [0.008561849594116211,
#   0.01860976219177246,
#   0.037626028060913086,
#   0.05770158767700195],
#  100: [0.013712644577026367,
#   0.027792692184448242,
#   0.05659794807434082,
#   0.08496952056884766],
#  128: [0.016077756881713867,
#   0.03406715393066406,
#   0.06746435165405273,
#   0.1062312126159668]}

# %%
sizes = [1000, 2000, 400, 5871]
